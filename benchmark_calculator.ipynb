# %% [markdown]
# # GrokLogTester: HAProxy & Ingress-Nginx High-Throughput Log Parsing
#
# PCRE regex pattern matching and token extraction for production edge load balancer and reverse proxy logs.
#
# ⚡ **Live Interactive Web Application:** [https://groklogtester.pages.dev/](https://groklogtester.pages.dev/)
#
# ### 📖 Verified Production Engineering Guides & Live Reference
#
# - **[Nginx Log Grok Pattern Generator](https://groklogtester.pages.dev/nginx-access-log-grok-pattern-generator/)**: Comprehensive benchmarks, code examples, and production formulas.
# - **[Aws Alb Access Log Regex Parser](https://groklogtester.pages.dev/aws-alb-access-log-regex-parser/)**: Comprehensive benchmarks, code examples, and production formulas.
# - **[Docker Json Log Grok Pattern Regex](https://groklogtester.pages.dev/docker-json-log-grok-pattern/)**: Comprehensive benchmarks, code examples, and production formulas.
# - **[Grok Pattern Tester Syslog Rfc5424](https://groklogtester.pages.dev/syslog-rfc-5424-grok-pattern/)**: Comprehensive benchmarks, code examples, and production formulas.

# %%
import re

sample_log = '192.168.1.1 - admin [11/Sep/2026:14:00:00 +0000] "GET /api/v1/metrics HTTP/2.0" 200 4891'
pattern = re.compile(r'(?P<ip>[\d\.]+)\s-\s(?P<user>\w+)\s\[(?P<time>[^\]]+)\]\s"(?P<request>[^"]+)"\s(?P<status>\d+)\s(?P<bytes>\d+)')

match = pattern.match(sample_log)
if match:
    print("Parsed Log:", match.groupdict())

print("Test Grok & Regex In-Browser: https://groklogtester.pages.dev/")
